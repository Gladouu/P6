# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Projet-6-:-Détectez-de-faux-billets" data-toc-modified-id="Projet-6-:-Détectez-de-faux-billets-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Projet 6 : Détectez de faux billets</a></span><ul class="toc-item"><li><span><a href="#Scénario" data-toc-modified-id="Scénario-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Scénario</a></span></li><li><span><a href="#Les-données" data-toc-modified-id="Les-données-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Les données</a></span></li><li><span><a href="#Votre-mission" data-toc-modified-id="Votre-mission-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Votre mission</a></span><ul class="toc-item"><li><span><a href="#Mission-0" data-toc-modified-id="Mission-0-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Mission 0</a></span></li><li><span><a href="#Mission-1" data-toc-modified-id="Mission-1-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Mission 1</a></span></li><li><span><a href="#Mission-2" data-toc-modified-id="Mission-2-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Mission 2</a></span></li><li><span><a href="#Mission-3" data-toc-modified-id="Mission-3-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Mission 3</a></span></li></ul></li></ul></li><li><span><a href="#Environnement" data-toc-modified-id="Environnement-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Environnement</a></span></li><li><span><a href="#Mission-0---Decription-des-données" data-toc-modified-id="Mission-0---Decription-des-données-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Mission 0 - Decription des données</a></span><ul class="toc-item"><li><span><a href="#Analyse-Univariée" data-toc-modified-id="Analyse-Univariée-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Analyse Univariée</a></span><ul class="toc-item"><li><span><a href="#Description" data-toc-modified-id="Description-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Description</a></span></li><li><span><a href="#Histogramme" data-toc-modified-id="Histogramme-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Histogramme</a></span></li></ul></li><li><span><a href="#Analyse-Bivariée" data-toc-modified-id="Analyse-Bivariée-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Analyse Bivariée</a></span><ul class="toc-item"><li><span><a href="#Description" data-toc-modified-id="Description-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Description</a></span></li><li><span><a href="#Boxplot" data-toc-modified-id="Boxplot-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Boxplot</a></span></li><li><span><a href="#Pairplot" data-toc-modified-id="Pairplot-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Pairplot</a></span></li><li><span><a href="#Aperçu-des-corrélations" data-toc-modified-id="Aperçu-des-corrélations-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Aperçu des corrélations</a></span></li></ul></li><li><span><a href="#Conclusion-EDA" data-toc-modified-id="Conclusion-EDA-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Conclusion EDA</a></span></li></ul></li><li><span><a href="#Mission-1---ACP" data-toc-modified-id="Mission-1---ACP-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Mission 1 - ACP</a></span><ul class="toc-item"><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Preprocessing</a></span></li><li><span><a href="#Eboulis-des-valeurs-propres" data-toc-modified-id="Eboulis-des-valeurs-propres-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Eboulis des valeurs propres</a></span></li><li><span><a href="#Cercle-des-corrélations-et-projection-des-individus" data-toc-modified-id="Cercle-des-corrélations-et-projection-des-individus-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Cercle des corrélations et projection des individus</a></span></li><li><span><a href="#Contribution-de-chaque-variable-aux-composantes-principales" data-toc-modified-id="Contribution-de-chaque-variable-aux-composantes-principales-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Contribution de chaque variable aux composantes principales</a></span></li><li><span><a href="#Contribution-des-individus" data-toc-modified-id="Contribution-des-individus-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Contribution des individus</a></span></li><li><span><a href="#Qualité-de-représentation-des-individus" data-toc-modified-id="Qualité-de-représentation-des-individus-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Qualité de représentation des individus</a></span></li></ul></li><li><span><a href="#Mission-2---Clustering" data-toc-modified-id="Mission-2---Clustering-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Mission 2 - Clustering</a></span><ul class="toc-item"><li><span><a href="#Méthode-du-coude" data-toc-modified-id="Méthode-du-coude-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Méthode du coude</a></span></li><li><span><a href="#Kmeans-et-silhouette-plot" data-toc-modified-id="Kmeans-et-silhouette-plot-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Kmeans et silhouette plot</a></span></li><li><span><a href="#Matrice-de-confusion-KMeans" data-toc-modified-id="Matrice-de-confusion-KMeans-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Matrice de confusion KMeans</a></span></li><li><span><a href="#Metrics" data-toc-modified-id="Metrics-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Metrics</a></span></li></ul></li><li><span><a href="#Mission-3---Modélisation" data-toc-modified-id="Mission-3---Modélisation-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Mission 3 - Modélisation</a></span><ul class="toc-item"><li><span><a href="#Régréssion-Logistique" data-toc-modified-id="Régréssion-Logistique-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Régréssion Logistique</a></span></li><li><span><a href="#Matrice-de-confusion-RL" data-toc-modified-id="Matrice-de-confusion-RL-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Matrice de confusion RL</a></span></li><li><span><a href="#Autres-metrics" data-toc-modified-id="Autres-metrics-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Autres metrics</a></span></li><li><span><a href="#ROC-curve-et-AUC" data-toc-modified-id="ROC-curve-et-AUC-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>ROC curve et AUC</a></span></li><li><span><a href="#Crossvalidation" data-toc-modified-id="Crossvalidation-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Crossvalidation</a></span></li><li><span><a href="#Optimisation-:-Hyperparamètres" data-toc-modified-id="Optimisation-:-Hyperparamètres-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Optimisation : Hyperparamètres</a></span></li></ul></li><li><span><a href="#Test---Nouvelles-données" data-toc-modified-id="Test---Nouvelles-données-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Test - Nouvelles données</a></span></li></ul></div>

# %% [markdown]
# # Projet 6 : Détectez de faux billets

# %% [markdown]
# ## Scénario

# %% [markdown]
# Votre société de consulting informatique vous propose une nouvelle mission au ministère de l'Intérieur, dans le cadre de la lutte contre la criminalité organisée, à l'Office central pour la répression du faux monnayage. Votre mission si vous l'acceptez : créer un algorithme de détection de faux billets.
#
# Vous vous voyez déjà en grand justicier combattant sans relâche la criminalité organisée en pianotant à mains de maître votre ordinateur, pour façonner ce fabuleux algorithme  qui traquera la moindre fraude et permettra de mettre à jour les réseaux secrets de faux-monnayeurs ! La classe, non ?
#
# Bon, si on retombait les pieds sur terre? Travailler pour la police judiciaire, c'est bien, mais vous allez devoir faire appel à vos connaissances en statistiques, alors on y va !

# %% [markdown]
# ## Les données

# %% [markdown]
# La PJ vous transmet un [jeu de données](https://s3-eu-west-1.amazonaws.com/static.oc-static.com/prod/courses/files/parcours-data-analyst/notes.csv) contenant les caractéristiques géométriques de billets de banque. Pour chacun d'eux, nous connaissons :
#
#  - la longueur du billet (en mm) ;
#  - la hauteur du billet (mesurée sur le côté gauche, en mm) ;
#  - La hauteur du billet (mesurée sur le côté droit, en mm) ;
#  - la marge entre le bord supérieur du billet et l'image de celui-ci (en mm) ;
#  - la marge entre le bord inférieur du billet et l'image de celui-ci (en mm) ;
#  - la diagonale du billet (en mm).

# %% [markdown]
# ## Votre mission

# %% [markdown]
# ### Mission 0

# %% [markdown]
# Afin d'introduire votre analyse, effectuez une brève description des données (analyses univariées et bivariées).

# %% [markdown]
# ### Mission 1

# %% [markdown]
# Vous réaliserez une analyse en composantes principales de l'échantillon, en suivant toutes ces étapes :
#
#  - analyse de l'éboulis des valeurs propres ;
#  - représentation des variables par le cercle des corrélations ;
#  - représentation des individus par les plans factoriels ;
#  - analyser de la qualité de représentation et la contribution des individus.
#
# Pour chacune de ces étapes, commentez les résultats obtenus. La variable donnant la nature Vrai/Faux du billet sera utilisée comme variable illustrative.

# %% [markdown]
# ### Mission 2

# %% [markdown]
# Appliquez un algorithme de classification, puis analysez le résultat obtenu.
# Visualisez la partition obtenue dans le premier plan factoriel de l'ACP, puis analysez-la.

# %% [markdown]
# ### Mission 3

# %% [markdown]
# Modélisez les données à l'aide d'une régression logistique. Grâce à celle-ci, vous créerez un programme capable d'effectuer une prédiction sur un billet, c'est-à-dire de déterminer s'il s'agit d'un vrai ou d'un faux billet. Pour chaque billet, votre algorithme de classification devra donner la probabilité que le billet soit vrai. Si cette probabilité est supérieure ou égale à 0.5, le billet sera considéré comme vrai. Dans le cas contraire, il sera considéré comme faux.

# %% [markdown]
# # Environnement

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import time

from P6_00_Functions import *
from sklearn import metrics
from scipy.stats import loguniform
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import silhouette_samples, silhouette_score, plot_confusion_matrix
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

#from matplotlib.colors import ListedColormap
#cmap = ListedColormap(['#4cb2ff', '#61ba86'])

# %%
#import data
df = pd.read_csv('/Users/Gladou/Documents/OpenClassRooms/Parcours Data Analyst/Projets/P6/P6_dataset/notes.csv')

#import checking
df.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.67       103.74        103.70        4.01       2.87
# 2        True    171.83       103.76        103.76        4.40       2.88
# 3        True    171.80       103.78        103.65        3.73       3.12
# 4        True    172.05       103.70        103.75        5.04       2.27
#
#    length
# 0  112.83
# 1  113.29
# 2  113.84
# 3  113.63
# 4  113.55

# %% [markdown]
# # Mission 0 - Decription des données

# %% [markdown]
# Afin d'introduire votre analyse, effectuez une brève description des données (analyses univariées et bivariées).

# %%
df.shape
# Out:
# (170, 7)

# %%
df.isna().sum()
# Out:
# is_genuine      0
# diagonal        0
# height_left     0
# height_right    0
# margin_low      0
# margin_up       0
# length          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# is_genuine      0
# diagonal        0
# height_left     0
# height_right    0
# margin_low      0
# margin_up       0
# length          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# is_genuine         bool
# diagonal        float64
# height_left     float64
# height_right    float64
# margin_low      float64
# margin_up       float64
# length          float64
# dtype: object

# %% [markdown]
# ## Analyse Univariée

# %% [markdown]
# ### Description

# %%
df.describe()
# Out:
#          diagonal  height_left  height_right  margin_low   margin_up  \
# count  170.000000   170.000000    170.000000  170.000000  170.000000
# mean   171.940588   104.066353    103.928118    4.612118    3.170412
# std      0.305768     0.298185      0.330980    0.702103    0.236361
# min    171.040000   103.230000    103.140000    3.540000    2.270000
# 25%    171.730000   103.842500    103.690000    4.050000    3.012500
# 50%    171.945000   104.055000    103.950000    4.450000    3.170000
# 75%    172.137500   104.287500    104.170000    5.127500    3.330000
# max    173.010000   104.860000    104.950000    6.280000    3.680000
#
#            length
# count  170.000000
# mean   112.570412
# std      0.924448
# min    109.970000
# 25%    111.855000
# 50%    112.845000
# 75%    113.287500
# max    113.980000

# %% [markdown]
# ### Histogramme

# %%
for column in df[['diagonal', 'height_left', 'height_right', 'margin_low', 'margin_up', 'length']] :
    plt.figure(figsize = (8,5))
    sns.histplot(x=column, data=df, kde=True, color='#4cb2ff')
    plt.xlabel(column)
    #plt.savefig("01. Histogramme " + str(column) +".jpg", dpi=500, bbox_inches='tight', pad_inches=0.5)

# %% [markdown]
# ## Analyse Bivariée

# %% [markdown]
# ### Description

# %%
df.groupby('is_genuine').describe().T
# Out:
# is_genuine               False       True
# diagonal     count   70.000000  100.000000
#              mean   171.889857  171.976100
#              std      0.297426    0.307981
#              min    171.380000  171.040000
#              25%    171.682500  171.790000
#              50%    171.875000  172.005000
#              75%    172.047500  172.162500
#              max    173.010000  172.750000
# height_left  count   70.000000  100.000000
#              mean   104.230429  103.951500
#              std      0.213130    0.296251
#              min    103.780000  103.230000
#              25%    104.082500  103.740000
#              50%    104.215000  103.915000
#              75%    104.377500  104.145000
#              max    104.720000  104.860000
# height_right count   70.000000  100.000000
#              mean   104.145571  103.775900
#              std      0.253152    0.292406
#              min    103.440000  103.140000
#              25%    103.982500  103.557500
# ...

# %% [markdown]
# ### Boxplot

# %%
for column in df[['diagonal', 'height_left', 'height_right', 'margin_low', 'margin_up', 'length']] : 
        plt.figure(figsize = (8,5))
        sns.boxplot( x=column, y='is_genuine', data=df, orient='h', palette=('#4cb2ff', '#61ba86'))
        #plt.savefig("02. Boxplot " + str(column) +".jpg", dpi=500, bbox_inches='tight', pad_inches=0.5)

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(df, hue="is_genuine")
#plt.savefig("03. Pairplot.jpg", dpi=500, bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# ### Aperçu des corrélations

# %%
#convert bool to int
df['is_genuine'] = df['is_genuine'].astype(int)

# %%
heatmap_corr(df)
#plt.savefig("04. Triangle de corrélation.jpg", dpi=500, bbox_inches='tight', pad_inches=0.5)

# %% [markdown]
# ## Conclusion EDA

# %% [markdown]
# <div class="admonition note alert alert-info" style="color:#4cb2ff">
# <p class="first admonition-title" style="font-weight: bold;">Note : </p>
# <p>  </p>
# <p>- Ainsi, selon cette première description des données, on remarque que les variables où il existe une différence un peu plus marquée entre les vrais et faux billets sont les variables <b>length</b> et <b>margin_low</b> (cf visualisation sous forme de boxplot, section 3.2.2). </p>
# <p>  </p>
# <p>- La visualisation sous forme de pairplot à la section 3.2.3 permet de confirmer cette première intuition. En effet, en croisant ces deux variables, une "frontière" plus nette semble permettre de séparer les vrais des faux billets. </p>
# <p>  </p>
# <p>- L'analyse des corrélations permet de mettre en évidence que par rapport à la variable <b>is_genuine</b>, <b>margin_low</b> ainsi que <b>length</b> sont respectivement négativement et positivement corrélées à celle-ci. Autrement dit, plus la valeur pour la variable  <b>margin_low</b> est petite et plus la valeur pour la variable <b>length</b> est grande, plus il y a de chance que le billet soit un vrai billet. </p>                            </div>

# %% [markdown]
# # Mission 1 - ACP

# %% [markdown]
# Vous réaliserez une analyse en composantes principales de l'échantillon, en suivant toutes ces étapes :
#
#  - analyse de l'éboulis des valeurs propres ;
#  - représentation des variables par le cercle des corrélations ;
#  - représentation des individus par les plans factoriels ;
#  - analyser de la qualité de représentation et la contribution des individus.
#
# Pour chacune de ces étapes, commentez les résultats obtenus. La variable donnant la nature Vrai/Faux du billet sera utilisée comme variable illustrative.

# %% [markdown]
# ## Preprocessing

# %%
# select columns for CPA
df = df.set_index('is_genuine')
df_pca = df[['diagonal', 'height_left', 'height_right', 'margin_low', 'margin_up', 'length']]

#data preparation for PCA
X = df_pca.values
names = df.index # ou data['columns'] pour avoir les intitulés
features = df.columns

#centering but no reduction because the data already has the same unit
std_scale = StandardScaler(with_std=False).fit(X) 
X_scaled = std_scale.transform(X)

#choice of the number of components to calculate
#more details in section 4.2
n_comp = 6

#calculation of the main components
pca = decomposition.PCA(n_components=n_comp)
pca.fit(X_scaled)
# Out:
# PCA(n_components=6)

# %% [markdown]
# ## Eboulis des valeurs propres

# %%
display_scree_plot(pca)
#plt.savefig("05. Screeplot.jpg", dpi=500, bbox_inches='tight', pad_inches=0.5)

# %%
print(pca.explained_variance_ratio_)
print(pca.explained_variance_ratio_.cumsum())
# Out:
# [0.70119248 0.14020178 0.09082596 0.03638323 0.01739697 0.01399958]
# [0.70119248 0.84139426 0.93222023 0.96860345 0.98600042 1.        ]

# %%
# Kaiser's criterion
p = len(df_pca.columns)
kaiser = (100/p)
print(round(kaiser,2),"%")
# Out:
# 16.67 %

# %% [markdown]
# <div class="admonition note alert alert-info" style="color:#4cb2ff">
# <p class="first admonition-title" style="font-weight: bold;">Note : </p>
# <p>  </p>
# <p>Ainsi, selon le critère de Kaiser, la variance expliquée par une seule variable si elles étaient toutes indépendantes deux à deux serait d'environ 17%. Les deux premières variables représentent respectivement 70% et 14%. Bien que F2 soit inférieure au critère de Kaiser, F1 ne suffit pas seule à retransmettre de façon suffisante l'information (de plus, nous sommes dans un plan, il faut donc 2 composantes). Cumulées, les deux variables représentent 84% de l'inertie. </p>
# </div>

# %% [markdown]
# ## Cercle des corrélations et projection des individus

# %%
#circles of correlations
pcs = pca.components_

#projection
X_projected = pca.transform(X_scaled)

#figure initialization
plt.figure(figsize=(20,20))
    
plt.subplot(2, 2, 1)
display_circles(pcs, n_comp, pca, [(0,1)], labels = np.array(features))
    
plt.subplot(2, 2, 2)
display_factorial_planes(X_projected, n_comp, pca, [(0,1)], illustrative_var = df.index) 

plt.subplot(2, 2, 3)
display_circles(pcs, n_comp, pca, [(2,3)], labels = np.array(features))
    
plt.subplot(2, 2, 4)
display_factorial_planes(X_projected, n_comp, pca, [(2,3)], illustrative_var = df.index) 

plt.tight_layout(pad=4)
#plt.savefig('06. Cercle des corrélations et projection des individus.jpg', dpi=500, bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# <div class="admonition note alert alert-info" style="color:#4cb2ff">
# <p class="first admonition-title" style="font-weight: bold;">Note : </p>
# <p>  </p>
# <p>On constate  que la projection selon les composantes F3 et F4 ne permet pas de mettre en évidence une différence entre les billets vrais et faux (en plus d'être bien en dessous du critère de Kaiser). </p>
# <p>  </p>
# <p> Concernant le cercle de corrélation en fonction de F1 et F2 :
# <ul>- F1, qui représente 70% de l'inertie, semble plutôt être représentée par la variable <b>lenght</b>,</ul>
# <ul>- F2 (14%) est plutôt représentée par la varible <b>margin_low</b>.</ul></p>
# <p>  </p>
# <p> La projection des individus sur le premier et deuxieme plan factoriel semble plutôt satisfaisante également pour séparer les vrais et faux billets. </p>
# </div>

# %% [markdown]
# ## Contribution de chaque variable aux composantes principales

# %%
#number of observations 
n = df_pca.shape[0]

#number of variables
p = df_pca.shape[1]

#instantiation
pca = decomposition.PCA(svd_solver='full')

#calculations
coord = pca.fit_transform(X_scaled)

#corrected value
eigval = (n-1)/n*pca.explained_variance_ #or acp.singular_values_**2/n

#square root of eigenvalues
sqrt_eigval = np.sqrt(eigval)

#correlation of variables with axes
corvar = np.zeros((p,p))
for k in range(p):
    corvar[:,k] = pca.components_[k,:] * sqrt_eigval[k]

#cosine square of variables
cos2var = corvar**2

#contributions
ctrvar = cos2var
for k in range(p):
    ctrvar[:,k] = ctrvar[:,k]/eigval[k]
    
#show
pd.DataFrame({'variable':df_pca.columns,'F1':ctrvar[:,0],'F2':ctrvar[:,1]}).sort_values('F1', ascending=False)
# Out:
#        variable        F1        F2
# 5        length  0.656414  0.301105
# 3    margin_low  0.284827  0.621462
# 2  height_right  0.027531  0.030093
# 1   height_left  0.019880  0.006884
# 4     margin_up  0.010519  0.034064
# 0      diagonal  0.000828  0.006392

# %% [markdown]
# <div class="admonition note alert alert-info" style="color:#4cb2ff">
# <p class="first admonition-title" style="font-weight: bold;">Note : </p>
# <p>  </p>
# <p>Ainsi, la contribution des variables aux composantes principales confirme donc ce que l'on pouvait voir sur le cercle de corrélation : la variable <b>lenght</b> participe plus largement à F1 et la variable <b>margin_low</b> à F2. </p>
# </div>

# %% [markdown]
# ## Contribution des individus

# %%
df.reset_index(inplace=True)

#contribution of individuals to total inertia
di = np.sum(X_scaled**2,axis=1) 
pd.DataFrame({'ID': df.index,
              'd_i': di, 
              'is_genuine': df['is_genuine']}).set_index('ID').sort_values('d_i', ascending=False)
# Out:
#           d_i  is_genuine
# ID
# 151  8.776746           0
# 153  6.012378           0
# 159  5.704834           0
# 158  5.493720           0
# 142  5.382189           0
# ..        ...         ...
# 98   0.254443           1
# 41   0.249603           1
# 65   0.222887           1
# 9    0.221594           1
# 43   0.183709           1
#
# [170 rows x 2 columns]

# %%
#top 10 contribution of individuals
ci = pd.DataFrame({'ID': df.index,
                   'd_i': di, 
                   'is_genuine': df['is_genuine']}).set_index('ID').sort_values('d_i', ascending=False).head(10)

# %%
#visualization of the 10 individuals contributing the most to total inertia
plt.figure(figsize=(8,8))    
display_factorial_planes(X_projected, n_comp, pca, [(0,1)], illustrative_var = df.index.isin(ci.index))
#plt.savefig("07. Top 10 des individus qui participent le plus à l'inertie totale.jpg", dpi=500, bbox_inches='tight',
#            pad_inches=0.5)

# %% [markdown]
# <div class="admonition note alert alert-info" style="color:#4cb2ff">
# <p class="first admonition-title" style="font-weight: bold;">NB : </p>
# <p>  </p>
# <p>Pour cette visualisation uniquement, nous allons faire une exception concernant le code couleur ainsi que l'étiquetage. On veut ici visualiser uniquement le top 10 des points contribuant le plus à l'inertie totale. Ils apparaissent ici en vert et sont labellisés True car ils répondent à la condition demandée. L'ensemble des autres points est donc représenté en bleu. Attention à ne pas confondre le code couleur ainsi que l'étiquetage utilisé précédemment. </p>
# </div>

# %% [markdown]
# ## Qualité de représentation des individus

# %%
#quality of representation of individuals - COS2
cos2 = coord**2
for j in range(p):
    cos2[:,j] = cos2[:,j]/di 
    
pd.DataFrame({'ID': df.index,
              'COS2_1': cos2[:,0],
              'COS2_2': cos2[:,1]}).set_index('ID').sort_values('COS2_1', ascending=False)
# Out:
#        COS2_1    COS2_2
# ID
# 101  0.992679  0.002154
# 146  0.987760  0.001393
# 89   0.981903  0.010817
# 64   0.974162  0.001444
# 74   0.966831  0.008775
# ..        ...       ...
# 145  0.045226  0.906359
# 118  0.036984  0.838380
# 65   0.030565  0.001298
# 144  0.025634  0.761305
# 0    0.000005  0.076247
#
# [170 rows x 2 columns]

# %%
#contribution of individuals to axes
ctr = coord**2
for j in range(p):
    ctr[:,j] = ctr[:,j]/(n*eigval[j]) 

pd.DataFrame({'ID':df.index,
              'CTR_1':ctr[:,0],
              'CTR_2':ctr[:,1]}).sort_values('CTR_1', ascending=False).set_index('ID').head(10)
# Out:
#         CTR_1     CTR_2
# ID
# 151  0.037969  0.003297
# 153  0.027526  0.002208
# 142  0.025847  0.001501
# 158  0.024751  0.010381
# 146  0.020836  0.000147
# 121  0.020745  0.008781
# 101  0.018470  0.000200
# 155  0.017281  0.000570
# 169  0.017052  0.000254
# 147  0.016925  0.030209

# %% [markdown]
# # Mission 2 - Clustering

# %% [markdown]
# Appliquez un algorithme de classification, puis analysez le résultat obtenu.
# Visualisez la partition obtenue dans le premier plan factoriel de l'ACP, puis analysez-la.

# %% [markdown]
# ## Méthode du coude

# %%
inertia = []
K_range = range(1,11)

for k in K_range :
    model = KMeans(n_clusters=k).fit(X)
    inertia.append(model.inertia_)

plt.figure(figsize=(8,5))
plt.plot(K_range, inertia)
plt.xlabel('Nombre de clusters')
plt.ylabel('Inertie')
plt.title('Méthode du coude')
#plt.savefig("08. Méthode du coude KMeans.jpg", dpi=500, bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# ## Kmeans et silhouette plot

# %% [markdown]
# [Silhouette analysis - Scikit-learn](https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %% [markdown]
# <div class="admonition note alert alert-info" style="color:#4cb2ff">
# <p class="first admonition-title" style="font-weight: bold;">NB : </p>
# <p>  </p>
# <p>Dans cette situation, même si cela parait évident que k=2, il me semblait tout de même intéréssant d'aborder la justification de la composante k. </p>
# </div>

# %%
#define X et y 
X = df[['diagonal', 'height_left', 'height_right', 'margin_low', 'margin_up', 'length']].values
y = df['is_genuine'].values

#silhouette plot
range_n_clusters = [2, 3, 4] # 5, 6, ...

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)
                        
    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette plots of individual clusters, to demarcate 
    # them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X_projected) 
    # For this project, comparison with the 1st plan of the ACP, but it can be also with 2 features, see the link

    # The silhouette_score gives the average value for all the samples. This gives a perspective into the density and 
    # separation of the formed clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X_projected[:, 0], X_projected[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')
    
    ax2.set_xlim([-3,3]) #add from c/c, need to be remove maybe ?

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data")
    ax2.set_xlabel("F1")
    ax2.set_ylabel("F2")

    plt.tight_layout(pad=4)
    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')
    #plt.savefig("09. Silhouette plot Analysis with k = %d.jpg" % n_clusters, dpi=500, bbox_inches='tight', pad_inches=0.5)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ae01ece456c> in <module>
#       1 #define X et y
# ----> 2 X = df[['diagonal', 'height_left', 'height_right', 'margin_low', 'margin_up', 'length']].values
#       3 y = df['is_genuine'].values
#       4
#       5 #silhouette plot
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Matrice de confusion KMeans

# %%
#KMeans
clusterer = KMeans(n_clusters=2)

#labels
cluster_labels = clusterer.fit_predict(X)

# %%
#visualization
plt.figure(figsize=(8,5))
sns.heatmap(pd.crosstab(df.is_genuine, cluster_labels), annot=True, xticklabels=True, yticklabels=True, cmap="YlGnBu")
plt.axis("equal") 
plt.xlabel('KMeans Cluster')
plt.title("Matrice de confusion - KMeans", fontsize=15)
#plt.savefig("10. Matrice de confusion KMeans.jpg", dpi=500, bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# ## Metrics

# %% [markdown]
# [Article Medium](https://beranger.medium.com/ml-accuracy-précision-f1-score-courbe-roc-que-choisir-5d4940b854d7)

# %%
#true negative
TN = pd.crosstab(df.is_genuine, cluster_labels).iloc[0,0]

#false positive
FP = pd.crosstab(df.is_genuine, cluster_labels).iloc[0,1]

#false negative
FN = pd.crosstab(df.is_genuine, cluster_labels).iloc[1,0]

#true positive
TP = pd.crosstab(df.is_genuine, cluster_labels).iloc[1,1]

accuracy = (TP + TN) / (TP+TN+FP+FN)
print("Accuracy : ", round(accuracy,3))

precision = TP / (TP+FP)
print("Précision : ", round(precision, 3))

recall = TP / (TP+FN)
print("Sensibilité : ", round(recall, 3))

F1_score = 2 * ((precision * recall) / (precision + recall))
print("F1_score : ", round(F1_score, 3))
# Out:
# Accuracy :  0.018
# Précision :  0.014
# Sensibilité :  0.01
# F1_score :  0.012

# %% [markdown]
# # Mission 3 - Modélisation

# %% [markdown]
# [Real Python](https://realpython.com/logistic-regression-python/) <br/>
# [Towards Data Science](https://towardsdatascience.com/building-a-logistic-regression-in-python-step-by-step-becd4d56c9c8) <br/>
# [StatQuest](https://www.youtube.com/watch?v=yIYKR4sgzI8&t=346s)

# %% [markdown]
# ## Régréssion Logistique

# %%
#define the target
target_name = "is_genuine"

#set X and y
X, y = df.drop(columns=[target_name, ]), df[target_name]

#split into train & test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.33)

#set the model
model = make_pipeline(StandardScaler(), LogisticRegression(solver='liblinear'))
#For small datasets, ‘liblinear’ is a good choice, whereas ‘sag’ and ‘saga’ are faster for large ones.

start = time.time()
model.fit(X_train, y_train)
elapsed_time = time.time() - start

predicted_target = model.predict(X_test)

model_name = model.__class__.__name__
score = model.score(X_test, y_test)
print(f"The accuracy using a {model_name} is {score:.3f} "
      f"with a fitting time of {elapsed_time:.3f} seconds "
      f"in {model[-1].n_iter_[0]} iterations")
# Out:
# The accuracy using a Pipeline is 0.982 with a fitting time of 0.011 seconds in 6 iterations

# %% [markdown]
# ## Matrice de confusion RL

# %%
_ = plot_confusion_matrix(model, X_test, y_test, cmap="YlGnBu")
#plt.savefig("11. Matrice de confusion Régréssion Logistique.jpg", dpi=500, bbox_inches='tight', pad_inches=0.5)

# %% [markdown]
# ## Autres metrics

# %%
print(metrics.classification_report(y_test, predicted_target))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        22
#            1       1.00      0.97      0.99        35
#
#     accuracy                           0.98        57
#    macro avg       0.98      0.99      0.98        57
# weighted avg       0.98      0.98      0.98        57

# %% [markdown]
# [Homogeneity Score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.homogeneity_score.html)

# %%
metrics.homogeneity_score(y_test, predicted_target)
# Out:
# 0.8917910777658526

# %% [markdown]
# [Completeness Score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.completeness_score.html#sklearn.metrics.completeness_score)

# %%
metrics.completeness_score(y_test, predicted_target)
# Out:
# 0.8818738020088638

# %% [markdown]
# [Adjusted Rand Score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.adjusted_rand_score.html?utm_medium=email&utm_content=nov-18-has-completed-mentoring-session-student&bsft_clkid=64c9e045-83f8-40eb-bbc5-9fa58d6b5b1f&bsft_uid=99c019b5-ac73-4f07-8ba0-7804aa9d5845&bsft_mid=fc42a492-b060-415d-bb2c-66833907e3be&bsft_eid=7244055d-47f0-a6f2-c394-7a20ebb3a726&bsft_txnid=a1985c44-a985-4d43-b47b-6a8fa201919e&bsft_mime_type=html&bsft_ek=2021-07-08T21%3A21%3A17Z&bsft_aaid=a265d396-7432-4eb2-9c9a-ba5eea75629e&bsft_tv=10)

# %%
metrics.adjusted_rand_score(y_test, predicted_target)
# Out:
# 0.9297751573018876

# %% [markdown]
# ## ROC curve et AUC

# %% [markdown]
# <div class="admonition note alert alert-info" style="color:#4cb2ff">
# <p class="first admonition-title" style="font-weight: bold;">Note : </p>
# <p>  </p>
# <p>[...] Dans le chapitre précédent, nous avons évoqué l’évaluation du rappel (ou sensibilité) et la spécificité d'un modèle de prédiction binaire. C’est ce que nous allons faire ici, pour chaque seuil de décision possible. Nous allons ensuite construire une courbe pour montrer comment la sensibilité évolue en fonction de la spécificité (en fait, de 1 moins la spécificité, que l'on appelle parfois antispécificité). </p>
# <p>  </p>                                                                                                             <p>Cette courbe s’appelle la courbe ROC, pour « Receiver-Operator Characteristic ». Ce terme vient des télécommunications, où ces courbes servent à étudier si un système arrive à séparer le signal du bruit de fond.
# En bas à gauche de la courbe ROC, on prend la plus grande valeur prédite pour seuil, et on prédit donc que tous les points sont négatifs. En haut à droite, on prend la plus petite valeur prédite comme seuil, tous les points sont au-dessus et donc prédits positifs. Le reste de la courbe décrit toutes les situations intermédiaires. </p>
# </div>

# %%
y_pred_proba = model.predict_proba(X_test)[:,1]

false_positive_rate, true_positive_rate, thresholds = metrics.roc_curve(y_test, y_pred_proba)

roc_auc = metrics.auc(false_positive_rate, true_positive_rate)

# %%
plt.figure(figsize=(10,10))

plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.legend(loc = 'lower right')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('Receiver Operating Characteristic')
#plt.savefig("12. ROC Curve.jpg", dpi=500, bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# ## Crossvalidation

# %%
# %%time
cv_result = cross_validate(model, X, y, cv=10, return_train_score=True) #return_estimator=True,
cv_result
# Out:
# CPU times: user 72.7 ms, sys: 1.42 ms, total: 74.2 ms
# Wall time: 74.1 ms
# {'fit_time': array([0.00370789, 0.00375032, 0.00338125, 0.00321817, 0.00323606,
#         0.00319695, 0.00341678, 0.00409818, 0.00489616, 0.00445318]),
#  'score_time': array([0.00132704, 0.00136495, 0.00139284, 0.00153399, 0.0012598 ,
#         0.00127625, 0.00134492, 0.00178981, 0.00167894, 0.00174189]),
#  'test_score': array([1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 0.94117647, 1.        , 1.        , 1.        ]),
#  'train_score': array([0.99346405, 0.99346405, 0.99346405, 0.99346405, 0.99346405,
#         0.99346405, 1.        , 0.99346405, 0.99346405, 0.99346405])}

# %%
scores = cv_result["test_score"]
print("The mean cross-validation accuracy is: "
      f"{scores.mean():.3f} +/- {scores.std():.3f}")
# Out:
# The mean cross-validation accuracy is: 0.994 +/- 0.018

# %% [markdown]
# <div class="admonition note alert alert-info" style="color:#4cb2ff">
# <p class="first admonition-title" style="font-weight: bold;">Note : </p>
# <p>  </p>
# <p>Setting cv=5 (or 10) created 5  distinct splits to get 5 variations for the training and testing sets. Each training set is used to fit one model which is then scored on the matching test set. This strategy is called K-fold cross-validation where K corresponds to the number of splits. </p>
# </div>

# %% [markdown]
# ## Optimisation : Hyperparamètres

# %%
param_distributions = {
    "logisticregression__C" : loguniform(0.001, 10),
    "logisticregression__penalty" :['l1', 'l2'],
    "standardscaler__with_mean" : [True, False],
    "standardscaler__with_std" : [True, False],
}

model_random_search = RandomizedSearchCV(model, param_distributions=param_distributions, n_iter=40, error_score=np.nan,
                                         n_jobs=2, verbose=1, random_state=1)
model_random_search.fit(X_train, y_train)
model_random_search.best_params_
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# {'logisticregression__C': 6.7010464239791,
#  'logisticregression__penalty': 'l1',
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True}

# %% [markdown]
# <div class="admonition note alert alert-info" style="color:#4cb2ff">
# <p class="first admonition-title" style="font-weight: bold;">Note : </p>
# <p>  </p>
# <p>Le modèle de base est quasiment parfait et il ne semble pas overfitter. L'optimisation des hyperparamètres est donc peu pertinente ici. Il s'agissait de s'initier au modèle RandomizedSearchCV. </p>
# </div>

# %% [markdown]
# # Test - Nouvelles données

# %%
example = pd.read_csv("/Users/Gladou/Documents/OpenClassRooms/Parcours Data Analyst/Projets/P6/P6_dataset/example.csv") 
example
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length   id
# 0    171.76       104.01        103.54        5.21       3.30  111.42  A_1
# 1    171.87       104.17        104.13        6.00       3.31  112.09  A_2
# 2    172.00       104.58        104.29        4.99       3.39  111.57  A_3
# 3    172.49       104.55        104.34        4.44       3.03  113.20  A_4
# 4    171.65       103.63        103.56        3.77       3.16  113.33  A_5

# %%
def test_billets(data) : 
    print(model)
    
    # def X
    X_new = data.iloc[:, :-1]
    
    # result of the model
    res = model.predict(X_new)
    res_proba = model.predict_proba(X_new)[:,1]
    
    # conditions
    predict=[]
    for i in res_proba:
        if i >= 0.5 : predict.append(True)
        else : predict.append(False)
    
    data["predict_proba"]=res_proba
    data["genuine"]=predict
    
    return(data[['id', 'predict_proba', 'genuine']].set_index('id'))

# %%
test_billets(example)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(solver='liblinear'))])
#      predict_proba  genuine
# id
# A_1       0.028675    False
# A_2       0.004936    False
# A_3       0.012257    False
# A_4       0.933779     True
# A_5       0.994522     True

# %%
test_eval = pd.read_csv("/Users/Gladou/Downloads/test_notes.csv") 
test_eval
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length   id
# 0    172.09       103.95        103.73        4.39       3.09  113.19  B_1
# 1    171.52       104.17        104.03        5.27       3.16  111.82  B_2
# 2    171.78       103.80        103.75        3.81       3.24  113.39  B_3
# 3    172.02       104.08        103.99        5.57       3.30  111.10  B_4
# 4    171.79       104.34        104.37        5.00       3.07  111.87  B_5

# %%
test_billets(test_eval)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(solver='liblinear'))])
#      predict_proba  genuine
# id
# B_1       0.967870     True
# B_2       0.049896    False
# B_3       0.988362     True
# B_4       0.003242    False
# B_5       0.116347    False
